# %% [markdown]
# # Video 7.5: Bayesian Inference

# %% [markdown]
# ## Video

# %%
# @markdown 
from IPython.display import YouTubeVideo
video = YouTubeVideo(id="FeikJ4qeAp0", width=730, height=410, fs=1)
print("Video available at https://youtube.com/watch?v=" + video.id)
video

# %% [markdown]
# ## Notes
#
# <a href="https://osf.io/yctd3/download">Click here to download notes</a>

# %%
# @markdown
from IPython.display import IFrame
IFrame(src="https://mfr.osf.io/render?url=https%3A%2F%2Fosf.io%2Fdownload%2Fyctd3%2F%3Fdirect%26mode%3Drender", width=730, height=1000)
