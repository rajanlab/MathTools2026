# %% [markdown]
# # Video 1.3: Linear combinations, span, and basis vectors

# %% [markdown]
# ## Video

# %%
# @markdown
from IPython.display import YouTubeVideo
video = YouTubeVideo(id="k7RM-ot2NWY", width=730, height=410, fs=1)
print("Video available at https://youtube.com/watch?v=" + video.id)
video

# %% [markdown]
# ## Notes
#
# These notes are not for the 3blue1brown video above but cover similar content and may be helpful.
#
# <a href="https://osf.io/wyck6/download">Click here to download notes</a>

# %%
# @markdown
from IPython.display import IFrame
IFrame(src="https://mfr.osf.io/render?url=https%3A%2F%2Fosf.io%2Fdownload%2Fwyck6%2F%3Fdirect%26mode%3Drender", width=730, height=1000)
