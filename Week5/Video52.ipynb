# %% [markdown]
# # Video 5.2: Matrix Decomposition & SVD

# %% [markdown]
# ## Video

# %%
# @markdown 
from IPython.display import YouTubeVideo
video = YouTubeVideo(id="KHafaOoAS8w", width=730, height=410, fs=1)
print("Video available at https://youtube.com/watch?v=" + video.id)
video

# %% [markdown]
# ## Notes
#
# <a href="https://osf.io/nptsc/download">
#     Click here to download notes
# </a>

# %%
# @markdown
from IPython.display import IFrame
IFrame(src="https://mfr.osf.io/render?url=https://osf.io/nptsc/?direct%26mode=render%26action=download%26mode=render", width=730, height=1000)
